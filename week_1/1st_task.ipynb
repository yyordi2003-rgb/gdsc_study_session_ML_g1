# %%
x= [2,5,76,34,98]
x
# Out:
# [2, 5, 76, 34, 98]

# %%
# change x into numpy array
import numpy as np
x= np.array(x)
x
# Out:
# array([ 2,  5, 76, 34, 98])

# %%
print("\n","Mean of x:", np.mean(x), "\n","Maximum of x:", np.max(x),"\n" ,"Sum of x:", np.sum(x))
# Out:
#  Mean of x: 43.0
#  Maximum of x: 98
#  Sum of x: 215
